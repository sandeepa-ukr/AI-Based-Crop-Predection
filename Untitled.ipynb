# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepa-ukr/AI-Based-Crop-Predection/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# ML imports
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.ensemble import IsolationForest
from scipy.cluster.hierarchy import dendrogram, linkage

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
crop_files = [
    ("apples.csv", "apples"),
    ("apricots.csv", "apricots"),
    ("areca nuts.csv", "areca nuts"),
    ("bananas.csv", "bananas"),
    ("barley.csv", "barley"),
    ("beans dry.csv", "beans dry"),
    ("beans green.csv", "beans green"),
    ("cabbage.csv", "cabbage"),
    ("carrots.csv", "carrots"),
    ("cashewnuts.csv", "cashewnuts"),
    ("cauliflower.csv", "cauliflower"),
    ("cherries.csv", "cherries"),
    ("chilli dry.csv", "chilli dry"),
    ("chilli green.csv", "chilli green"),
    ("coconuts.csv", "coconuts"),
    ("coffee.csv", "coffee"),
    ("cucumber.csv", "cucumber"),
    ("eggplant.csv", "eggplant"),
    ("fennel coriander.csv", "fennel coriander"),
    ("garlic.csv", "garlic"),
    ("ginger.csv", "ginger"),
    ("grapes.csv", "grapes"),
    ("groundnuts.csv", "groundnuts"),
    ("lemons.csv", "lemons"),
    ("lentils.csv", "lentils"),
    ("lettuce.csv", "lettuce"),
    ("maize.csv", "maize"),
    ("mangoes.csv", "mangoes"),
    ("melons.csv", "melons"),
    ("nutmeg.csv", "nutmeg"),
    ("okra.csv", "okra"),
    ("onions.csv", "onions"),
    ("oranges.csv", "oranges"),
    ("papaya.csv", "papaya"),
    ("peaches.csv", "peaches"),
    ("pears.csv", "pears"),
    ("peas.csv", "peas"),
    ("pepper.csv", "pepper"),
    ("pineapples.csv", "pineapples"),
    ("potatoes.csv", "potatoes"),
    ("pumpkins.csv", "pumpkins"),
    ("rice.csv", "rice"),
    ("safflower.csv", "safflower"),
    ("sesame.csv", "sesame"),
    ("soyabean.csv", "soyabean"),
    ("sugarcane.csv", "sugarcane"),
    ("tomatoes.csv", "tomatoes"),
    ("watermelon.csv", "watermelon"),
    ("wheat.csv", "wheat"),
]

# %%
crop_dfs = []
for fname, crop_name in crop_files:
    tmp = pd.read_csv(fname)
    # tmp = tmp.copy()
    # tmp['Year'] = tmp['Year'].astype(int)
    # tmp['crop_type'] = crop_name
    crop_dfs.append(tmp)

crop_df = pd.concat(crop_dfs, ignore_index=True, axis=0)
print(f"Loaded crop_df shape: {crop_df.shape}")
# Out:
# Loaded crop_df shape: (8526, 14)

# %%
crop_df
# Out:
#      Domain Code                        Domain  Area Code (FAO)   Area  \
# 0            QCL  Crops and livestock products              100  India
# 1            QCL  Crops and livestock products              100  India
# 2            QCL  Crops and livestock products              100  India
# 3            QCL  Crops and livestock products              100  India
# 4            QCL  Crops and livestock products              100  India
# ...          ...                           ...              ...    ...
# 8521         QCL  Crops and livestock products              100  India
# 8522         QCL  Crops and livestock products              100  India
# 8523         QCL  Crops and livestock products              100  India
# 8524         QCL  Crops and livestock products              100  India
# 8525         QCL  Crops and livestock products              100  India
#
#       Element Code         Element  Item Code (FAO)    Item  Year Code  Year  \
# 0             5312  Area harvested              515  Apples       1961  1961
# 1             5312  Area harvested              515  Apples       1962  1962
# 2             5312  Area harvested              515  Apples       1963  1963
# 3             5312  Area harvested              515  Apples       1964  1964
# 4             5312  Area harvested              515  Apples       1965  1965
# ...            ...             ...              ...     ...        ...   ...
# 8521          5510      Production               15   Wheat       2014  2014
# 8522          5510      Production               15   Wheat       2015  2015
# 8523          5510      Production               15   Wheat       2016  2016
# 8524          5510      Production               15   Wheat       2017  2017
# 8525          5510      Production               15   Wheat       2018  2018
#
#         Unit     Value Flag Flag Description
# 0         ha     44500    F     FAO estimate
# 1         ha     38500    F     FAO estimate
# 2         ha     33700    F     FAO estimate
# 3         ha     26500    F     FAO estimate
# 4         ha     21700    F     FAO estimate
# ...      ...       ...  ...              ...
# 8521  tonnes  95850000  NaN    Official data
# 8522  tonnes  86530000  NaN    Official data
# 8523  tonnes  92290000  NaN    Official data
# 8524  tonnes  98510220  NaN    Official data
# 8525  tonnes  99869520  NaN    Official data
#
# [8526 rows x 14 columns]

# %%
ftest_df = pd.read_csv('FTest_features.csv')

# %%
ftest_df
# Out:
#       Year   APR    AUG   DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC  \
# 0     1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 1     1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 2     1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 3     1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 4     1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# ...    ...   ...    ...   ...     ...      ...      ...      ...      ...
# 2837  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 2838  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 2839  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 2840  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 2841  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
#
#       climate_std  target_yield
# 0      116.831600         41573
# 1      116.831600         27586
# 2      116.831600          8889
# 3      116.831600        136788
# 4      116.831600          8796
# ...           ...           ...
# 2837    98.010202         10585
# 2838    98.010202        801984
# 2839    98.010202        250431
# 2840    98.010202        249505
# 2841    98.010202         33682
#
# [2842 rows x 11 columns]

# %%
combined_df = pd.merge(ftest_df, crop_df, on='Year', how='left')
print(combined_df.head())
# Out:
#    Year   APR    AUG   DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC  \
# 0  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 1  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 2  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 3  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 4  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
#
#    climate_std  ...   Area Element Code         Element  Item Code (FAO)  \
# 0     116.8316  ...  India         5312  Area harvested              515
# 1     116.8316  ...  India         5419           Yield              515
# 2     116.8316  ...  India         5510      Production              515
# 3     116.8316  ...  India         5312  Area harvested              526
# 4     116.8316  ...  India         5419           Yield              526
#
#        Item  Year Code    Unit   Value Flag  Flag Description
# 0    Apples       1961      ha   44500    F      FAO estimate
# 1    Apples       1961   hg/ha   41573   Fc   Calculated data
# 2    Apples       1961  tonnes  185000  NaN     Official data
# 3  Apricots       1961      ha    2900    F      FAO estimate
# 4  Apricots       1961   hg/ha   27586   Fc   Calculated data
#
# [5 rows x 24 columns]

# %%
combined_df.head(20)
# Out:
#     Year   APR    AUG   DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC  \
# 0   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 1   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 2   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 3   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 4   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 5   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 6   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 7   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 8   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 9   1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 10  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 11  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 12  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 13  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 14  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 15  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 16  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 17  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 18  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
# 19  1961  28.5  287.6  10.4    24.0    18.98    26.11    27.06    21.17
#
#     climate_std  ...   Area Element Code         Element  Item Code (FAO)  \
# 0      116.8316  ...  India         5312  Area harvested              515
# 1      116.8316  ...  India         5419           Yield              515
# 2      116.8316  ...  India         5510      Production              515
# 3      116.8316  ...  India         5312  Area harvested              526
# 4      116.8316  ...  India         5419           Yield              526
# 5      116.8316  ...  India         5510      Production              526
# 6      116.8316  ...  India         5312  Area harvested              226
# 7      116.8316  ...  India         5419           Yield              226
# 8      116.8316  ...  India         5510      Production              226
# 9      116.8316  ...  India         5312  Area harvested              486
# 10     116.8316  ...  India         5419           Yield              486
# 11     116.8316  ...  India         5510      Production              486
# 12     116.8316  ...  India         5312  Area harvested               44
# 13     116.8316  ...  India         5419           Yield               44
# 14     116.8316  ...  India         5510      Production               44
# 15     116.8316  ...  India         5312  Area harvested              176
# 16     116.8316  ...  India         5419           Yield              176
# 17     116.8316  ...  India         5510      Production              176
# 18     116.8316  ...  India         5312  Area harvested              414
# 19     116.8316  ...  India         5419           Yield              414
#
#             Item  Year Code    Unit    Value Flag  Flag Description
# 0         Apples       1961      ha    44500    F      FAO estimate
# 1         Apples       1961   hg/ha    41573   Fc   Calculated data
# 2         Apples       1961  tonnes   185000  NaN     Official data
# 3       Apricots       1961      ha     2900    F      FAO estimate
# 4       Apricots       1961   hg/ha    27586   Fc   Calculated data
# 5       Apricots       1961  tonnes     8000  NaN     Official data
# 6     Areca nuts       1961      ha   135000    F      FAO estimate
# 7     Areca nuts       1961   hg/ha     8889   Fc   Calculated data
# 8     Areca nuts       1961  tonnes   120000    F      FAO estimate
# 9        Bananas       1961      ha   165000  NaN     Official data
# 10       Bananas       1961   hg/ha   136788   Fc   Calculated data
# 11       Bananas       1961  tonnes  2257000  NaN     Official data
# 12        Barley       1961      ha  3205000  NaN     Official data
# 13        Barley       1961   hg/ha     8796   Fc   Calculated data
# 14        Barley       1961  tonnes  2819000  NaN     Official data
# 15    Beans, dry       1961      ha  6541248  NaN     Official data
# 16    Beans, dry       1961   hg/ha     2577   Fc   Calculated data
# 17    Beans, dry       1961  tonnes  1685627  NaN     Official data
# 18  Beans, green       1961      ha    80000    F      FAO estimate
# 19  Beans, green       1961   hg/ha    23125   Fc   Calculated data
#
# [20 rows x 24 columns]

# %%
combined_df.shape
# Out:
# (417774, 24)

# %%
combined_df.columns
# Out:
# Index(['Year', 'APR', 'AUG', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC', 'climate_std', 'target_yield', 'Domain Code', 'Domain',
#        'Area Code (FAO)', 'Area', 'Element Code', 'Element', 'Item Code (FAO)',
#        'Item', 'Year Code', 'Unit', 'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
train_data= combined_df.drop(columns=['Domain Code', 'Domain',
       'Area Code (FAO)', 'Area', 'Element Code', 'Item Code (FAO)',
       'Year Code', 'Flag', 'Flag Description'])

# %%
train_data
# Out:
#         Year   APR    AUG   DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC  \
# 0       1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 1       1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 2       1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 3       1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# 4       1961  28.5  287.6  10.4   24.00    18.98    26.11    27.06    21.17
# ...      ...   ...    ...   ...     ...      ...      ...      ...      ...
# 417769  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 417770  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 417771  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 417772  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
# 417773  2018  39.5  259.4  18.9   25.09    21.24    28.16    28.28    23.55
#
#         climate_std  target_yield         Element         Item    Unit  \
# 0        116.831600         41573  Area harvested       Apples      ha
# 1        116.831600         41573           Yield       Apples   hg/ha
# 2        116.831600         41573      Production       Apples  tonnes
# 3        116.831600         41573  Area harvested     Apricots      ha
# 4        116.831600         41573           Yield     Apricots   hg/ha
# ...             ...           ...             ...          ...     ...
# 417769    98.010202         33682           Yield  Watermelons   hg/ha
# 417770    98.010202         33682      Production  Watermelons  tonnes
# 417771    98.010202         33682  Area harvested        Wheat      ha
# 417772    98.010202         33682           Yield        Wheat   hg/ha
# 417773    98.010202         33682      Production        Wheat  tonnes
#
#            Value
# 0          44500
# 1          41573
# 2         185000
# 3           2900
# 4          27586
# ...          ...
# 417769    249505
# 417770   2520000
# 417771  29650590
# 417772     33682
# 417773  99869520
#
# [417774 rows x 15 columns]

# %%
train_data.columns
# Out:
# Index(['Year', 'APR', 'AUG', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
#        'OCT-DEC', 'climate_std', 'target_yield', 'Element', 'Item', 'Unit',
#        'Value'],
#       dtype='object')

# %%
# Select only numerical features for unsupervised learning
numerical_features = train_data.select_dtypes(include=[np.number]).columns.tolist()
# numerical_features.remove('target_yield')

# # Remove Year if it's not meaningful for clustering
# if 'Year' in numerical_features:
#     numerical_features.remove('Year')

print(f"Numerical features for clustering: {numerical_features}")

X = train_data[numerical_features].copy()

# Handle missing values
if X.isnull().any().any():
    from sklearn.impute import SimpleImputer
    imputer = SimpleImputer(strategy='median')
    X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)
    print(f"Missing values handled: {X.isnull().sum().sum()} remaining")

# Scale the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

print(f"Final feature matrix shape: {X_scaled_df.shape}")
# Out:
# Numerical features for clustering: ['Year', 'APR', 'AUG', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP', 'OCT-DEC', 'climate_std', 'target_yield', 'Value']
# Final feature matrix shape: (417774, 12)

# %%
X_scaled_df
# Out:
#             Year       APR       AUG       DEC    ANNUAL   JAN-FEB   MAR-MAY  \
# 0      -1.702441 -1.009677  0.983885 -0.606159 -1.264155 -0.782054 -0.324238
# 1      -1.702441 -1.009677  0.983885 -0.606159 -1.264155 -0.782054 -0.324238
# 2      -1.702441 -1.009677  0.983885 -0.606159 -1.264155 -0.782054 -0.324238
# 3      -1.702441 -1.009677  0.983885 -0.606159 -1.264155 -0.782054 -0.324238
# 4      -1.702441 -1.009677  0.983885 -0.606159 -1.264155 -0.782054 -0.324238
# ...          ...       ...       ...       ...       ...       ...       ...
# 417769  1.702441  0.138378  0.086021  0.287223  1.729099  2.171320  2.589734
# 417770  1.702441  0.138378  0.086021  0.287223  1.729099  2.171320  2.589734
# 417771  1.702441  0.138378  0.086021  0.287223  1.729099  2.171320  2.589734
# 417772  1.702441  0.138378  0.086021  0.287223  1.729099  2.171320  2.589734
# 417773  1.702441  0.138378  0.086021  0.287223  1.729099  2.171320  2.589734
#
#          JUN-SEP   OCT-DEC  climate_std  target_yield     Value
# 0      -0.857215 -1.717277     1.885730     -0.385122 -0.184624
# 1      -0.857215 -1.717277     1.885730     -0.385122 -0.184755
# 2      -0.857215 -1.717277     1.885730     -0.385122 -0.178314
# 3      -0.857215 -1.717277     1.885730     -0.385122 -0.186492
# 4      -0.857215 -1.717277     1.885730     -0.385122 -0.185383
# ...          ...       ...          ...           ...       ...
# 417769  2.419746  2.254123    -0.031857     -0.460934 -0.175417
# 417770  2.419746  2.254123    -0.031857     -0.460934 -0.073448
# 417771  2.419746  2.254123    -0.031857     -0.460934  1.144997
# 417772  2.419746  2.254123    -0.031857     -0.460934 -0.185109
# 417773  2.419746  2.254123    -0.031857     -0.460934  4.298555
#
# [417774 rows x 12 columns]

# %%
X_scaled_df.shape
# Out:
# (417774, 12)

# %%
X_sample = X_scaled_df

# %%
X_sample = X_scaled_df.sample(5000, random_state=42)

# %%
X_sample
# Out:
#             Year       APR       AUG       DEC    ANNUAL   JAN-FEB   MAR-MAY  \
# 407977  1.642706  0.347116  0.114676  0.329265  0.905268  2.955401  2.945097
# 181490 -0.209072  1.234249 -0.904178  1.285709 -0.714934 -0.599101 -0.565884
# 46307  -1.344032 -0.905308  0.242033  4.197084 -0.962084 -0.180925 -1.120249
# 341751  1.105093 -0.905308  0.289791 -0.543097  0.410969 -0.546829  0.173270
# 43597  -1.344032 -0.905308  0.242033  4.197084 -0.962084 -0.180925 -1.120249
# ...          ...       ...       ...       ...       ...       ...       ...
# 355632  1.224563  0.086194  0.573160  0.686618  1.838943  0.799177  2.120656
# 102303 -0.866154 -1.030550  1.139897 -1.352396 -1.978143 -1.161026 -0.807530
# 45481  -1.344032 -0.905308  0.242033  4.197084 -0.962084 -0.180925 -1.120249
# 37003  -1.403767 -0.790503 -1.407237  0.055995 -0.275557  0.459409 -0.381096
# 388780  1.463502 -1.667199 -0.611257 -0.574628  0.740501  0.002028 -0.139449
#
#          JUN-SEP   OCT-DEC  climate_std  target_yield     Value
# 407977  3.010673  3.355436     0.027280      0.865282 -0.178957
# 181490 -0.561752 -0.499158    -1.319685     -0.741077 -0.094556
# 46307  -0.508031 -0.866262     0.354579      0.771600 -0.180919
# 341751 -0.320008  1.119438    -0.150025      1.666770  1.858479
# 43597  -0.508031 -0.866262     0.354579     -0.696575 -0.179886
# ...          ...       ...          ...           ...       ...
# 355632  0.324640  0.668901     0.510329     -0.713753 -0.186299
# 102303 -2.173372 -1.500351     1.634190     -0.746188 -0.182131
# 45481  -0.508031 -0.866262     0.354579     -0.724677 -0.184959
# 37003  -0.561752 -0.615964    -1.342119     -0.558152 -0.183916
# 388780  1.345332  0.451975    -0.790733      1.534054 -0.186437
#
# [5000 rows x 12 columns]

# %%
# Find optimal number of clusters using elbow method
inertia = []
silhouette_scores = []
k_range = range(2, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(X_sample)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(X_sample, cluster_labels))

# Plot elbow curve and silhouette scores
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

ax1.plot(k_range, inertia, marker='o')
ax1.set_xlabel('Number of Clusters')
ax1.set_ylabel('Inertia')
ax1.set_title('Elbow Method')
ax1.grid(True)

ax2.plot(k_range, silhouette_scores, marker='o', color='orange')
ax2.set_xlabel('Number of Clusters')
ax2.set_ylabel('Silhouette Score')
ax2.set_title('Silhouette Scores')
ax2.grid(True)

plt.tight_layout()
plt.show()

# Choose optimal k (you can adjust based on the plots)
optimal_k = 4  # Change based on elbow/silhouette analysis
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_sample)

# Add cluster labels to original data
train_data['cluster'] = cluster_labels

print(f"Cluster distribution:")
print(train_data['cluster'].value_counts().sort_index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1774219869.py in <cell line: 0>()
#      34
#      35 # Add cluster labels to original data
# ---> 36 train_data['cluster'] = cluster_labels
#      37
#      38 print(f"Cluster distribution:")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (5000) does not match length of index (417774)

# %%
# Start with PATTERN DISCOVERY + CLUSTERING combined
# def comprehensive_analysis(train_data):
print("=== PATTERN DISCOVERY ===")

    # 1. Climate-Crop Relationships
if 'Item' in train_data.columns:
    crop_climate_corr = train_data.groupby('Item')[[
        'Year', 'APR', 'AUG', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
       'OCT-DEC'
    ]].mean()

    print("Top climate patterns by crop:")
    print(crop_climate_corr.head(10))

    # 2. Seasonal Patterns
# print("\n=== SEASONAL ANALYSIS ===")
# seasonal_impact = train_data.groupby('Item')[[
#     'winter_avg', 'summer_avg', 'monsoon_avg'
# ]].mean()
# print("Seasonal climate preferences by crop:")
# print(seasonal_impact.head(10))

    # 3. CLUSTERING Analysis
print("\n=== CLUSTERING ANALYSIS ===")
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

    # Prepare features (exclude non-numerical)
features = ['Year', 'APR', 'AUG', 'DEC', 'ANNUAL', 'JAN-FEB', 'MAR-MAY', 'JUN-SEP',
       'OCT-DEC', 'climate_std', 'target_yield', 'Value']

X = train_data[features].dropna()
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

    # Analyze clusters
train_data_clustered = train_data.copy()
train_data_clustered = train_data_clustered.loc[X.index]  # Align indices
train_data_clustered['cluster'] = clusters

print("Cluster Profiles:")
for cluster_id in range(4):
    cluster_data = train_data_clustered[train_data_clustered['cluster'] == cluster_id]
    print(f"\n📍 Cluster {cluster_id} ({len(cluster_data)} records):")
    if 'Item' in cluster_data.columns:
        top_crops = cluster_data['Item'].value_counts().head(3)
        print(f"   Common crops: {dict(top_crops)}")
    # print(f"   Avg annual climate: {cluster_data['ANN'].mean():.1f}")
    print(f"   Climate variability: {cluster_data['climate_std'].mean():.1f}")

# return train_data_clustered

# Run the analysis
# enhanced_data = comprehensive_analysis(train_data)

# %% [markdown]
# #Add Cluster Labels to the clusters

# %%
print(train_data_clustered['cluster'].value_counts())

# %%
train_data_clustered['cluster'] = cluster_labels

final_df = train_data_clustered

# %%
cluster_0 = final_df[final_df['cluster'] == 0]
cluster_1 = final_df[final_df['cluster'] == 1]
cluster_2 = final_df[final_df['cluster'] == 2]
cluster_3 = final_df[final_df['cluster'] == 3]
